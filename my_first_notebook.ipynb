# %% [markdown]
# Hardware refers to the physical components of a computer, such as the CPU or keyboard.
# Software refers to the programs and applications that run on hardware, such as Microsoft Word.
# Example of hardware: Monitor. Example of software: Google Chrome.
